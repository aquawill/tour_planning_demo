# %%
# getting OAuth access token

from requests_oauthlib import OAuth1Session
import pprint

client_key = '' # your HERE location Services access key
client_secret = '' # your HERE location Services access secret

request_token_url = 'https://stg.account.api.here.com/oauth2/token'
data = {'grant_type': 'client_credentials'}
headers = {'Content-Type': 'application/x-www-form-urlencoded'}

oauth = OAuth1Session(client_key, client_secret=client_secret)
oauth_result = oauth.fetch_request_token(request_token_url, headers=headers, data=data)
pprint.pprint(oauth_result)
# Out:
# {'access_token': 'eyJhbGciOiJSUzUxMiIsImN0eSI6IkpXVCIsImlzcyI6IkhFUkUiLCJhaWQiOiJRZFk3VGJuQ0diSmV6aTQ2ZVNHayIsImlhdCI6MTU5NDg2NTIwOCwiZXhwIjoxNTk0OTUxNjA4LCJraWQiOiJqMSJ9..eCz_15sT52GJ0s8SYWqjxzw0r8S0NJGCpCet1_GDeGd7vN_rKtLH564N3gglcqQNWIRSLuaQIfaLyljAfJH6FLEFYkSVQxCS1-vXECbAS5ZBqlMOckfJT8pJdbnD4KoEVRMG7ZylDhmCrrdaBqpPJOJvOrtN03WsX0JTBeaj2x1HgU47rEMy-9vn8XQALFpg4KswnGxBb-PLVdCWptbD2Urzp_Xr3LequSQEP3pMKg02920eiM5O2xlj_JdUGe-xz7WOw1d4NbdF-GX0hj3Pfd0osZH7mLZJ8Q0yVCNrTxO7QF-DuRLLOizTJSCnr_uekiHctgKQUFsA_4F2u6PlBw',
#  'expires_in': 86399,
#  'token_type': 'bearer'}

# %%
# delivery target listing

import csv
destinations = 'destinations.csv'
destination_list = []
f = open(destinations, encoding='utf-8')
csv = csv.DictReader(f)
for row in csv:
    destination_list.append(row)
print(destination_list)
# Out:
# [{'customer_id': 'c000001', 'name': '肯德基-花蓮中正餐廳', 'latitude': '23.97929', 'longitude': '121.61043', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000002', 'name': '肯德基-台北台大餐廳', 'latitude': '25.01707', 'longitude': '121.53325', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000003', 'name': '肯德基-彰化員林餐廳', 'latitude': '23.95943', 'longitude': '120.57111', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000004', 'name': '肯德基-中和興南餐廳', 'latitude': '24.98914', 'longitude': '121.50996', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000005', 'name': '肯德基-嘉義忠孝餐廳', 'latitude': '23.49499', 'longitude': '120.45175', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000006', 'name': '肯德基-高雄十全餐廳', 'latitude': '22.64501', 'longitude': '120.30923', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000007', 'name': '肯德基-土城裕民餐廳', 'latitude': '24.98545', 'longitude': '121.45267', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000008', 'name': '肯德基-台北石牌餐廳', 'latitude': '25.11494', 'longitude': '121.51556', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000009', 'name': '肯德基-嘉義垂楊餐廳', 'latitude': '23.47376', 'longitude': '120.44832', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000010', 'name': '肯德基-中和福祥餐廳', 'latitude': '25.00264', 'longitude': '121.49895', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000011', 'name': '肯德基-台北中崙餐廳', 'latitude': '25.04721', 'longitude': '121.54245', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'time_start': '2020-08-25T01:00:00Z', 'time_end': '2020-08-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000012', 'name': '肯德基-高雄岡山餐廳', 'latitude': '22.79388', 'longitude': '120.29578', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': ' ...

# %%
# delivery vehicle listing

import csv

destinations = 'fleet.csv'
f = open(destinations, encoding='utf-8')
csv = csv.reader(f)
for row in csv:
    print(row)
# Out:
# ['vehicle_id', 'type', 'name', 'cost_distance', 'cost_time', 'cost_fixed', 'shift_start', 'shift_end', 'start_latitude', 'start_longitude', 'end_latitude', 'end_longitude', 'break_start', 'break_end', 'break_duration', 'capacity_mass', 'capacity_size', 'max_distance', 'shift_time', 'amount']
# ['isuzu', 'truck', 'ISUZU_NLR', '0.004', '0.033', '1600', '2020-08-25T00:00:00Z', '2020-08-25T09:00:00Z', '24.970504', '121.2516', '24.970504', '121.2516', '2020-08-25T04:00:00Z', '2020-08-25T05:00:00Z', '3600', '3500', '40', '600000', '28800', '5']
# ['mitsubishi', 'truck', 'MITSUBISHI_CANTER', '0.005', '0.04', '2000', '2020-08-25T00:00:00Z', '2020-08-25T09:00:00Z', '24.970504', '121.2516', '24.970504', '121.2516', '2020-08-25T04:00:00Z', '2020-08-25T05:00:00Z', '3600', '3500', '50', '600000', '28800', '5']

# %%
# composing HERE Tour Planning API request body

import csv
import json
import uuid

destinations = 'destinations.csv'
vehicles = 'fleet.csv'

jobs = []
types = []
profiles = []

with open(destinations, encoding='utf-8') as destinations:
    reader = csv.DictReader(destinations)
    for row in reader:
        job_type = row['job_type']
        if job_type == 'delivery':
            jobs.append({'id': row['customer_id'],
                         'places':
                             {'delivery':
                                  {'location':
                                       {'lat': float(row['latitude']),
                                        'lng': float(row['longitude'])},
                                   'times': [[row['time_start'],
                                              row['time_end']]],
                                   'duration': int(row['duration']),
                                   'tag': row['customer_id']
                                   }
                              },
                         'demand': [int(row['mass']),
                                    int(row['size'])]
                         }
                        )
        else:
            jobs.append({'id': row['customer_id'],
                         'places':
                             {'pickup':
                                  {'location':
                                       {'lat': float(row['latitude']),
                                        'lng': float(row['longitude'])},
                                   'times': [[row['time_start'],
                                              row['time_end']]],
                                   'duration': int(row['duration']),
                                   'tag': row['customer_id']
                                   }
                              },
                         'demand': [int(row['mass']),
                                    int(row['size'])]
                         }
                        )

with open(vehicles, encoding='utf-8') as vehicle_list:
    reader = csv.DictReader(vehicle_list)
    for row in reader:
        types.append({
            "id": row['vehicle_id'],
            "profile": row['name'],
            "costs": {
                "fixed": float(row['cost_fixed']),
                "distance": float(row['cost_distance']),
                "time": float(row['cost_time'])
            },
            "shifts": [
                {
                    "start": {
                        "time": row['shift_start'],
                        "location": {
                            "lat": float(row['start_latitude']),
                            "lng": float(row['start_longitude'])
                        }
                    },
                    "end": {
                        "time": row['shift_end'],
                        "location": {
                            "lat": float(row['end_latitude']),
                            "lng": float(row['end_longitude'])
                        }
                    },
                    "breaks": [
                        {
                            "times": [
                                [
                                    row['break_start'],
                                    row['break_end']
                                ]
                            ],
                            "duration": int(row['break_duration']),
                        }
                    ]
                }
            ],
            "capacity": [
                int(row['capacity_mass']),
                int(row['capacity_size'])
            ],
            "skills": [
                "fridge"
            ],
            "limits": {
                "maxDistance": int(row['max_distance']),
                "shiftTime": int(row['shift_time'])
            },
            "amount": int(row['amount'])
        })
        profiles.append({
            "name": row['name'],
            "type": row['type']
        })

problem = {
    "id": str(uuid.uuid4()),
    "plan": {
        "jobs": jobs,
    },
    "fleet": {
        "types": types,
        "profiles": profiles
    },
    "configuration": {
        "optimizations": {
            "waitingTime": {
                "reduce": True,
                "bufferTime": 15
            }
        }
    }
}

data = json.dumps(problem, ensure_ascii=False)

print(data)
# Out:
# {"id": "45e368bb-d134-4c5a-aad3-24e8663b942b", "plan": {"jobs": [{"id": "c000001", "places": {"delivery": {"location": {"lat": 23.97929, "lng": 121.61043}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 600, "tag": "c000001"}}, "demand": [100, 1]}, {"id": "c000002", "places": {"delivery": {"location": {"lat": 25.01707, "lng": 121.53325}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 300, "tag": "c000002"}}, "demand": [50, 1]}, {"id": "c000003", "places": {"delivery": {"location": {"lat": 23.95943, "lng": 120.57111}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 600, "tag": "c000003"}}, "demand": [100, 1]}, {"id": "c000004", "places": {"delivery": {"location": {"lat": 24.98914, "lng": 121.50996}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 300, "tag": "c000004"}}, "demand": [50, 1]}, {"id": "c000005", "places": {"delivery": {"location": {"lat": 23.49499, "lng": 120.45175}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 600, "tag": "c000005"}}, "demand": [100, 1]}, {"id": "c000006", "places": {"delivery": {"location": {"lat": 22.64501, "lng": 120.30923}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 300, "tag": "c000006"}}, "demand": [50, 1]}, {"id": "c000007", "places": {"delivery": {"location": {"lat": 24.98545, "lng": 121.45267}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 600, "tag": "c000007"}}, "demand": [100, 1]}, {"id": "c000008", "places": {"delivery": {"location": {"lat": 25.11494, "lng": 121.51556}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 300, "tag": "c000008"}}, "demand": [50, 1]}, {"id": "c000009", "places": {"delivery": {"location": {"lat": 23.47376, "lng": 120.44832}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 600, "tag": "c000009"}}, "demand": [100, 1]}, {"id": "c000010", "places": {"delivery": {"location": {"lat": 25.00264, "lng": 121.49895}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 300, "tag": "c000010"}}, "demand": [50, 1]}, {"id": "c000011", "places": {"delivery": {"location": {"lat": 25.04721, "lng": 121.54245}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 600, "tag": "c000011"}}, "demand": [100, 1]}, {"id": "c000012", "places": {"delivery": {"location": {"lat": 22.79388, "lng": 120.29578}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 300, "tag": "c000012"}}, "demand": [50, 1]}, {"id": "c000013", "places": {"delivery": {"location": {"lat": 23.00881, "lng": 120.20743}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 600, "tag": "c000013"}}, "demand": [100, 1]}, {"id": "c000014", "places": {"delivery": {"location": {"lat": 25.14038, "lng": 121.45975}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 300, "tag": "c000014"}}, "demand": [50, 1]}, {"id": "c000015", "places": {"delivery": {"location": {"lat": 22.56732, "lng": 120.35157}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 600, "tag": "c000015"}}, "demand": [100, 1]}, {"id": "c000016", "places": {"delivery": {"location": {"lat": 25.04663, "lng": 121.51537}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 300, "tag": "c000016"}}, "demand": [50, 1]}, {"id": "c000017", "places": {"delivery": {"location": {"lat": 24.98616, "lng": 121.46479}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 600, "tag": "c000017"}}, "demand": [100, 1]}, {"id": "c000018", "places": {"delivery": {"location": {"lat": 25.01751, "lng": 121.47736}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration": 300, "tag": "c000018"}}, "demand": [50, 1]}, {"id": "c000019", "places": {"delivery": {"location": {"lat": 22.62448, "lng": 120.35702}, "times": [["2020-08-25T01:00:00Z", "2020-08-25T09:00:00Z"]], "duration":  ...

# %%
# request HERE Tour Planning API to get planning results

import requests
import solution

tour_planning_api_url = "https://vrp.cit.api.here.com/v1/problems"

headers = {
  'Content-Type': 'application/json',
  'Authorization': '{} {}'.format(oauth_result['token_type'], oauth_result['access_token'])
}

r = requests.request('POST', tour_planning_api_url, headers=headers, data = data)
j = json.loads(r.text)

print('response_time: {}'.format(r.elapsed.total_seconds()))
print('tour planning result: {}'.format(j['statistic']))
# Out:
# response_time: 21.11473
# tour planning result: {'cost': 37530.86299999998, 'distance': 2160221, 'duration': 277840, 'times': {'driving': 190840, 'serving': 51000, 'waiting': 0, 'break': 36000}}

# %%
import folium
from math import radians, cos, sin, degrees, atan2, atan, tan, acos
import requests
from folium.plugins import BeautifyIcon, AntPath
import solution
import json
import random


def get_degree(latA, lonA, latB, lonB):
    radLatA = radians(latA)
    radLonA = radians(lonA)
    radLatB = radians(latB)
    radLonB = radians(lonB)
    dLon = radLonB - radLonA
    y = sin(dLon) * cos(radLatB)
    x = cos(radLatA) * sin(radLatB) - sin(radLatA) * cos(radLatB) * cos(dLon)
    brng = degrees(atan2(y, x))
    brng = (brng + 360) % 360
    return brng


def get_route(ori_lat, ori_lon, dest_lat, dest_lon, route_mode, departure_time):
    route_url = 'https://route.ls.hereapi.com/routing/7.2/calculateroute.json?'
    wp0 = ('{},{}'.format(ori_lat, ori_lon))
    wp1 = ('{},{}'.format(dest_lat, dest_lon))
    route_options = '&mode={}&departure={}&legAttributes=shape'.format(route_mode, departure_time)
    url = route_url + 'apiKey=' + apikey + '&waypoint0=geo!' + wp0 + '&waypoint1=geo!' + wp1 + route_options
    json_result = json.loads(requests.get(url).text)
    routes = json_result['response']['route']
    route_shape = []
    for route in routes:
        legs = route['leg']
        for leg in legs:
            shape = leg['shape']
            point_index = 0
            while point_index < len(shape):
                point = shape[point_index]
                lat = float(point.split(',')[0])
                lon = float(point.split(',')[1])
                if point_index < len(shape) - 1:
                    avg_lat = (float(lat) + float(shape[point_index + 1].split(',')[0])) / 2
                    avg_lon = (float(lon) + float(shape[point_index + 1].split(',')[1])) / 2
                    bearing = get_degree(lat, lon, float(shape[point_index + 1].split(',')[0]), float(shape[point_index + 1].split(',')[1]))
                route_shape.append(([lat, lon], [avg_lat, avg_lon], bearing))
                point_index += 1
    return route_shape


apikey = '' # your HERE location Services API Key

m = folium.Map(
    #     tiles='https://1.base.maps.ls.hereapi.com/maptile/2.1/maptile/newest/normal.day/{z}/{x}/{y}/256/png8?lg=cht&&apiKey=' + apikey,
    location=[23, 121],
    max_zoom=20,
    attr='(c)1987-2018 HERE'
)
folium.Marker([24.970504, 121.2516], icon=BeautifyIcon(icon='home', iconShape='marker', background_color='#000000', text_color='#FFFFFF'), popup='Home').add_to(m)

bounds = []

customer_dict = {}
unreachable_customer_names = []
solution = solution.solution_from_dict(j)
unassigned = solution.unassigned
unassigned_feature_group = folium.map.FeatureGroup(name='Unassigned', overlay=True, control=True, show=True)
icon_color = '#FF0000'
for destination_dict in destination_list:
    customer_dict[destination_dict['customer_id']] = destination_dict['name']
    for unassigned_destination in unassigned:
        job_id = unassigned_destination.job_id
        customer_name = ''
        if destination_dict['customer_id'] == job_id:
            customer_name = destination_dict['name']
            unreachable_customer_names.append(customer_name)
            folium.Marker([destination_dict['latitude'], destination_dict['longitude']], icon=BeautifyIcon(icon='ban', iconShape='marker', background_color=icon_color, border_width=2), popup='{}/{}<br>{}'.format(job_id, customer_name, unassigned_destination.reasons.__getitem__(0).description)).add_to(unassigned_feature_group)
unassigned_feature_group.add_to(m)
print("unreachable customers: ")
print(unreachable_customer_names)

tour_index = 0
tour_list = []
while tour_index < len(solution.tours):
    icon_color = '#'
    i = 0
    while i < 6:
        icon_color += hex(random.randint(6, 16))[-1]
        i += 1
    tour = solution.tours.__getitem__(tour_index)
    vehicle_id = tour.vehicle_id
    print("calculating routes for tour: {} / vehicle: {} / {} stops".format(tour_index, vehicle_id, len(tour.stops)))
    feature_group = folium.map.FeatureGroup(name=vehicle_id, overlay=True, control=True, show=True)
    type_id = tour.type_id
    stops = tour.stops
    stop_index = 0
    stop_list = []
    while stop_index < len(stops):
        stop = stops.__getitem__(stop_index)
        stop_location = stop.location.to_dict()
        stop_time = stop.time
        stop_time_arrival = stop.time.arrival
        stop_time_departure = stop.time.departure
        stop_activities = stop.activities
        for stop_activity in stop_activities:
            job_id = stop_activity.job_id
            for destination_dict in destination_list:
                if destination_dict['customer_id'] == job_id:
                    stop_list.append({'stop_index': stop_index, 'job_id': job_id,'destination' : destination_dict})
                elif job_id == 'departure' or job_id == 'arrival' or job_id == 'break':
                    stop_list.append({'stop_index': stop_index, 'job_id': job_id, 'destination' : {'latitude': stop_location['lat'], 'longitude': stop_location['lng']}})
                    break
            customer_name = customer_dict.get(job_id)
            stop_load = stop.load
            if stop_index < len(stops) - 1:
                route_shape = get_route(stop_location['lat'], stop_location['lng'], stops.__getitem__(stop_index + 1).location.to_dict()['lat'], stops.__getitem__(stop_index + 1).location.to_dict()['lng'], 'truck;fastest', stop_time_departure.strftime('%Y-%m-%dT%H:%M:%SZ'))
                if stop_index > 0:
                    folium.Marker([stop_location['lat'], stop_location['lng']], icon=BeautifyIcon(icon='flag', iconShape='marker', background_color=icon_color, border_width=2), popup='Vehicle ID: {}<br>Job ID: {}/{}<br>Arrival：{}<br>Departure：{}'.format(vehicle_id, job_id, customer_name, stop_time_arrival, stop_time_departure)).add_to(feature_group)
                shape_point_index = 0
                bounds.append([stop_location['lat'], stop_location['lng']])
                shape_point_list = []
                while shape_point_index < len(route_shape):
                    shape_point = route_shape[shape_point_index]
                    shape_point_list.append(shape_point[0])
                    shape_point_index += 1
                AntPath(shape_point_list, color=icon_color, weight=4, opacity=1).add_to(feature_group)
            print('{} --> {}/{}/{}'.format(stop_index, job_id, customer_name, [stop_location['lat'], stop_location['lng']]))
        stop_index += 1
    statistic = tour.statistic
    tour_list.append({'vehicle_id': vehicle_id, 'stop_list': stop_list})
    feature_group.add_to(m)
    tour_index += 1
# Out:
# unreachable customers:
# ['肯德基-花蓮中正餐廳', '肯德基-嘉義忠孝餐廳', '肯德基-高雄十全餐廳', '肯德基-嘉義垂楊餐廳', '肯德基-高雄岡山餐廳', '肯德基-台南西門二餐廳', '肯德基-高雄沿海餐廳', '肯德基-鳳山中山餐廳', '肯德基-高雄楠梓二餐廳', '肯德基-宜蘭家樂福餐廳', '肯德基-宜蘭新興餐廳', '肯德基-高雄中華五餐廳', '肯德基-台南永康餐廳', '肯德基-高雄站前餐廳', '肯德基-高雄三多餐廳', '肯德基-台南東門餐廳', '肯德基-宜蘭羅東餐廳', '肯德基-台東新生餐廳', '肯德基-台南安平餐廳', '肯德基-高雄大順二餐廳', '肯德基-台南中華餐廳', '肯德基-鳳山五甲二餐廳', '肯德基-嘉義中興餐廳', '肯德基-高雄大順餐廳', '肯德基-高雄自由餐廳', '肯德基-屏東逢甲餐廳', '肯德基-鳳山五甲一餐廳', '肯德基-南投埔里餐廳', '肯德基-雲林虎尾餐廳', '肯德基-台南崇明餐廳', '肯德基-台南中華西餐廳', '肯德基-斗六民生餐廳', '肯德基-屏東自由餐廳', '肯德基-彰化鹿港餐廳', '肯德基-左營環球餐廳', '肯德基-新營中正餐廳', '肯德基-台南善化餐廳', '肯德基-台南成大餐廳', '肯德基-高雄後昌餐廳', '肯德基-台南海佃餐廳', '肯德基-羅東興東餐廳', '肯德基-台南海佃餐廳', '肯德基-高雄文化餐廳', '肯德基-宜蘭舊城餐廳', '肯德基-台南金華餐廳']
# calculating routes for tour: 0 / vehicle: isuzu_2 / 16 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000133/肯德基-台北南港餐廳/[25.05579, 121.61395]
# 2 --> c000090/肯德基-基隆忠二餐廳/[25.12979, 121.74067]
# 3 --> c000046/肯德基-基隆仁一餐廳/[25.12789, 121.75095]
# 4 --> c000127/肯德基-士林文昌餐廳/[25.09447, 121.5223]
# 5 --> c000039/肯德基-台北士林餐廳/[25.0873, 121.5259]
# 6 --> c000148/肯德基-天母中山餐廳/[25.11824, 121.53014]
# 7 --> c000098/肯德基-台北天母餐廳/[25.11811, 121.53084]
# 8 --> c000130/Kfc肯德基/[25.11456, 121.51752]
# 9 --> c000008/肯德基-台北石牌餐廳/[25.11494, 121.51556]
# 10 --> c000057/肯德基-北投光明餐廳/[25.13673, 121.50431]
# 11 --> c000066/肯德基-南崁中正餐廳/[25.04407, 121.29408]
# 11 --> break/None/[25.04407, 121.29408]
# 12 --> c000059/肯德基-桃園台茂餐廳/[25.05292, 121.28768]
# 13 --> c000060/肯德基-林口復興餐廳/[25.05909, 121.36743]
# 14 --> c000135/肯德基-桃園大園餐廳/[25.06246, 121.20148]
# 15 --> arrival/None/[24.970504, 121.2516]
# calculating routes for tour: 1 / vehicle: isuzu_3 / 12 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000030/肯德基-苗栗頭份餐廳/[24.69083, 120.91315]
# 2 --> c000089/肯德基-苗栗中正餐廳/[24.55175, 120.81604]
# 3 --> c000103/肯德基-台中豐原餐廳/[24.25304, 120.72189]
# 4 --> break/None/[24.78667, 121.01074]
# 4 --> c000128/肯德基-新竹光復餐廳/[24.78667, 121.01074]
# 5 --> c000145/肯德基-新竹清大餐廳/[24.79592, 120.99814]
# 6 --> c000026/肯德基-新竹亞太餐廳/[24.80531, 120.9862]
# 7 --> c000031/肯德基-新竹民生餐廳/[24.81355, 120.97438]
# 8 --> c000159/肯德基-新竹新豐餐廳/[24.8678, 120.99374]
# 9 --> c000027/肯德基-楊梅中山餐廳/[24.90889, 121.16696]
# 10 --> c000146/肯德基-楊梅大成餐廳/[24.9104, 121.14567]
# 11 --> arrival/None/[24.970504, 121.2516]
# calculating routes for tour: 2 / vehicle: isuzu_4 / 11 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000067/肯德基-台中大雅餐廳/[24.2254, 120.64533]
# 2 --> c000150/肯德基-台中潭子餐廳/[24.21387, 120.70055]
# 3 --> c000113/肯德基-北屯大買家餐廳/[24.17624, 120.69952]
# 4 --> c000022/肯德基-太平中山餐廳/[24.14981, 120.71283]
# 5 --> c000045/肯德基-大里中興餐廳/[24.1104, 120.69003]
# 6 --> c000102/肯德基-大里國光餐廳/[24.10062, 120.68234]
# 7 --> c000094/肯德基-台中五權西餐廳/[24.14006, 120.65156]
# 8 --> c000080/肯德基-中港愛買餐廳/[24.16183, 120.65072]
# 9 --> c000023/肯德基-台中三越餐廳/[24.16563, 120.6438]
# 9 --> break/None/[24.16563, 120.6438]
# 10 --> arrival/None/[24.970504, 121.2516]
# calculating routes for tour: 3 / vehicle: isuzu_5 / 10 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000020/肯德基-彰化金馬餐廳/[24.09398, 120.54057]
# 2 --> c000140/肯德基-彰化民權餐廳/[24.07694, 120.53719]
# 3 --> c000043/肯德基-彰化中山餐廳/[24.06824, 120.54014]
# 4 --> c000125/肯德基-台中烏日餐廳/[24.10725, 120.63624]
# 5 --> c000036/肯德基-台中復興餐廳/[24.11732, 120.658]
# 6 --> break/None/[24.15036, 120.67641]
# 6 --> c000063/肯德基-台中五權餐廳/[24.15036, 120.67641]
# 7 --> c000093/肯德基-台中文心餐廳/[24.17358, 120.67646]
# 8 --> c000076/肯德基-新竹竹北餐廳/[24.82645, 121.01085]
# 9 --> arrival/None/[24.970504, 121.2516]
# calculating routes for tour: 4 / vehicle: isuzu_1 / 7 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000003/肯德基-彰化員林餐廳/[23.95943, 120.57111]
# 2 --> c000131/肯德基-南投南崗餐廳/[23.91154, 120.67872]
# 3 --> c000071/肯德基-南投草屯餐廳/[23.97505, 120.68364]
# 3 --> break/None/[23.97505, 120.68364]
# 4 --> c000050/肯德基-中壢民族餐廳/[24.95739, 121.20469]
# 5 --> c000048/肯德基-中壢中正餐廳/[24.95537, 121.22162]
# 6 --> arrival/None/[24.970504, 121.2516]
# calculating routes for tour: 5 / vehicle: mitsubishi_2 / 17 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000126/肯德基-竹北自強餐廳/[24.81657, 121.02569]
# 2 --> c000158/肯德基-竹北自強餐廳/[24.81074, 121.02149]
# 3 --> c000096/肯德基-新竹竹東餐廳/[24.7428, 121.08422]
# 4 --> c000160/肯德基-龍潭北龍餐廳/[24.86458, 121.211]
# 5 --> c000029/肯德基-龍潭北龍餐廳/[24.86839, 121.21836]
# 6 --> c000004/肯德基-中和興南餐廳/[24.98914, 121.50996]
# 7 --> c000010/肯德基-中和福祥餐廳/[25.00264, 121.49895]
# 8 --> c000124/肯德基-台北萬大餐廳/[25.02543, 121.50039]
# 9 --> break/None/[25.01751, 121.47736]
# 9 --> c000018/肯德基-板橋埔墘餐廳/[25.01751, 121.47736]
# 10 --> c000091/肯德基-板橋新埔餐廳/[25.02277, 121.46726]
# 11 --> c000129/肯德基-板橋中山二餐廳/[25.00961, 121.46117]
# 12 --> c000100/肯德基-樹林中山餐廳/[24.99192, 121.4237]
# 13 --> c000106/肯德基-桃園中正餐廳/[24.99061, 121.31294]
# 14 --> c000092/肯德基-桃園中山餐廳/[24.99077, 121.2904]
# 15 --> c000147/肯德基-桃園中山餐廳/[24.97461, 121.26382]
# 16 --> arrival/None/[24.970504, 121.2516]
# calculating routes for tour: 6 / vehicle: mitsubishi_3 / 18 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000108/肯德基-中和環球餐廳/[25.00609, 121.47514]
# 2 --> c000154/肯德基-台北峨嵋餐廳/[25.04348, 121.50713]
# 3 --> c000117/肯德基-台北車站B1餐廳/[25.04745, 121.51614]
# 3 --> c000118/肯德基-台北車站B2餐廳/[25.04745, 121.51614]
# 4 --> c000079/肯德基-台北承德餐廳/[25.05076, 121.51689]
# 5 --> c000078/肯德基-台北雙連餐廳/[25.0578, 121.52166]
# 6 --> c000097/肯德基-台北南京西餐廳/[25.05267, 121.52003]
# 7 --> c000055/肯德基-台北中山餐廳/[25.05177, 121.5436]
# 8 --> c000011/肯德基-台北中崙餐廳/[25.04721, 121.54245]
# 9 --> c000138/肯德基-三重三和餐廳/[25.0363, 121.55691]
# 10 --> c000109/肯德基-台北莊敬餐廳/[25.02795, 121.56387]
# 11 --> break/None/[25.041, 121.57313]
# 11 --> c000077/肯德基-台北永春餐廳/[25.041, 121.57313]
# 12 --> c000074/肯德基-台北內湖餐廳/[25.08252, 121.56485]
# 13 --> c000049/肯德基-台北東湖二餐廳/[25.06821, 121.61631]
# 14 --> c000114/肯德基-汐止中興餐廳/[25.06633, 121.6309]
# 15 --> c000141/肯德基-汐止大同餐廳/[25.06729, 121.65759]
# 16 --> c000051/肯德基-林口文化餐廳/[25.06991, 121.37173]
# 17 --> arrival/None/[24.970504, 121.2516]
# calculating routes for tour: 7 / vehicle: mitsubishi_4 / 9 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000081/肯德基-台中后庄餐廳/[24.18977, 120.66255]
# 2 --> c000119/肯德基-台中中港愛買餐廳/[24.1748, 120.66333]
# 3 --> c000037/肯德基-台中永福餐廳/[24.18456, 120.62095]
# 4 --> c000157/肯德基-台中台糖餐廳/[24.18367, 120.61457]
# 5 --> c000084/肯德基-台中沙鹿餐廳/[24.23578, 120.55913]
# 6 --> break/None/[24.33462, 120.61525]
# 6 --> c000061/肯德基-台中烏日餐廳/[24.33462, 120.61525]
# 7 --> c000075/肯德基-中壢中和餐廳/[24.95413, 121.22565]
# 8 --> arrival/None/[24.970504, 121.2516]
# calculating routes for tour: 8 / vehicle: mitsubishi_5 / 16 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000014/肯德基-淡水竹圍餐廳/[25.14038, 121.45975]
# 2 --> c000132/肯德基-淡水中山二餐廳/[25.16965, 121.44437]
# 3 --> c000101/肯德基-淡水中山餐廳/[25.17742, 121.44318]
# 4 --> c000021/肯德基-蘆洲三民餐廳/[25.08714, 121.47138]
# 5 --> c000032/肯德基-三重三和餐廳/[25.07921, 121.48224]
# 6 --> c000153/肯德基-三重正義餐廳/[25.06667, 121.4966]
# 7 --> c000082/肯德基-三重重新二餐廳/[25.06293, 121.49969]
# 8 --> c000025/肯德基-新莊中港餐廳/[25.0447, 121.45266]
# 9 --> c000134/肯德基-新莊輔大餐廳/[25.03231, 121.43346]
# 10 --> break/None/[25.02345, 121.42558]
# 10 --> c000068/肯德基-新莊民安餐廳/[25.02345, 121.42558]
# 11 --> c000136/肯德基-桃園桃鶯餐廳/[24.98354, 121.31872]
# 12 --> c000073/肯德基-桃園經國餐廳/[25.01499, 121.30609]
# 13 --> c000042/肯德基-桃園大興西餐廳/[25.01052, 121.2969]
# 14 --> c000034/肯德基-中壢環中東餐廳/[24.96236, 121.25531]
# 15 --> arrival/None/[24.970504, 121.2516]
# calculating routes for tour: 9 / vehicle: mitsubishi_1 / 18 stops
# 0 --> departure/None/[24.970504, 121.2516]
# 1 --> c000137/肯德基-五股成泰餐廳/[25.08458, 121.4385]
# 2 --> c000107/肯德基-泰山明志餐廳/[25.05904, 121.43136]
# 3 --> c000016/肯德基-台北三越餐廳/[25.04663, 121.51537]
# 4 --> c000002/肯德基-台北台大餐廳/[25.01707, 121.53325]
# 5 --> c000122/肯德基-文山興隆餐廳/[25.00079, 121.55484]
# 6 --> c000151/肯德基-文山木柵餐廳/[24.98858, 121.56681]
# 7 --> c000088/肯德基-新店光明餐廳/[24.95911, 121.53831]
# 8 --> c000086/肯德基-新店北新餐廳/[24.97327, 121.54287]
# 9 --> c000038/肯德基-永和中正餐廳/[24.99907, 121.51711]
# 10 --> break/None/[25.0062, 121.50575]
# 10 --> c000155/肯德基-永和中山餐廳/[25.0062, 121.50575]
# 11 --> c000052/肯德基-中和連城餐廳/[24.9962, 121.48799]
# 12 --> c000017/肯德基-台北土城餐廳/[24.98616, 121.46479]
# 13 --> c000115/肯德基-土城金城餐廳/[24.98584, 121.46398]
# 14 --> c000007/肯德基-土城裕民餐廳/[24.98545, 121.45267]
# 15 --> c000110/肯德基-三峽北大餐廳/[24.94458, 121.37405]
# 16 --> c000072/肯德基-桃園八德餐廳/[24.95411, 121.29861]
# 17 --> arrival/None/[24.970504, 121.2516]

# %%
folium.LayerControl(collapsed=False).add_to(m)
m.fit_bounds(bounds)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ec57bbbc5bc94da58eeac60da0152511%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/marslan390/BeautifyMarker/master/leaflet-beautify-marker-icon.css%22/%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//rawcdn.githack.com/marslan390/BeautifyMarker/master/leaflet-beautify-marker-icon.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-ant-path%401.1.2/dist/leaflet-ant-path.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ec57bbbc5bc94da58eeac60da0152511%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A ...

# %%
m.save('map.html')
